# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import chisquare

# %%
def getData(files):
    f = open("data/"+str(files), "r")
    f1 = f.readlines()
    del f1[0:4]
    a = np.asarray(f1)
    table = []
    for i in range(0, len(a)):
        b = a[i][0:-1].split('\t')
        c = map(float, b[0:6])
        d = np.asarray(c)
        table.append(d)
    table = np.asarray(table)
    pd.set_option('display.float_format', lambda x: '%.6e' % x)
    df = pd.DataFrame(table, columns=['t1', 'v1', 'w1', 't2', 'v2', 'w2'])
    return df

# %%
def getChiSq(y, y_fit, sigma):
    chi_sq = 0
    for i in range(len(y)):
        chi_sq += ( (y[i] - y_fit[i]) / sigma[i] )**2
    return chi_sq

# %%
from scipy.stats import chi2

def getRedChi2(y, y_fit, sigma, numPar=2):
    chi_sq = getChiSq(y, y_fit, sigma)
    red_chi_sq = chi_sq / (len(y) - numPar)
    p = chi2.pdf(chi_sq, df=(len(y) - numPar))
    print 'reduced chi-square =', '%.2f'%(red_chi_sq), 'p-value =', '%.2f'%(p)
    return red_chi_sq

# %%
df = getData('MUO_long.dat')

# %%
plt.hist(df['v1'], bins=28, range=(0,0.7), alpha=0.5, label='first pulse')
plt.hist(df['v2'], bins=28, range=(0,0.7), alpha=0.5, label='second pulse')
plt.xlabel('Height of the pulses (V)', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of counts', fontsize=15)
plt.yticks(fontsize=15)
plt.yscale('log')
plt.legend(prop={'size': 15}, frameon=False, loc='best')

# %%
plt.hist(df['w1'], bins=20, range=(0, 4e-7), alpha=0.5, label='first pulse')
plt.hist(df['w2'], bins=20, range=(0, 4e-7), alpha=0.5, label='second pulse')
plt.xlabel('Width of the pulses (s)', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Number of counts', fontsize=15)
plt.yticks(fontsize=15)
plt.yscale('log')
plt.legend(prop={'size': 15}, frameon=False, loc='best')

# %%
df.eval('dt = t2 - t1', inplace=True)
print min(df['dt']), max(df['dt'])
# Out:
# 1e-06 4.0732e-05

# %%
plt.hist(df['dt'], bins = 100, range=(1e-6, 4e-5), normed=True)
plt.xlabel('Time difference between the pulses dt (s)', fontsize=12.5)
plt.xticks(fontsize=12.5)
plt.ylabel('Number of counts', fontsize=12.5)
plt.yticks(fontsize=12.5)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
# Out:
# /home/youqi/.local/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
def decay(x, tau, c):
    return np.exp(- x / tau) + c

# %%
plt.hist(df['dt']*1e6, bins = 100, range=(2, 10), normed=True)
plt.xlabel('Time difference between the pulses dt ($\mu$s)', fontsize=12.5)
plt.xticks(fontsize=12.5)
plt.ylabel('counts', fontsize=12.5)
plt.yticks(fontsize=12.5)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Signal + background')
# Out:
# Text(0.5,1,'Signal + background')

# %%
y, binEdges = np.histogram(df['dt']*1e6, bins=100, range=(2, 7), density=True)
x = []
for i in range(len(y)):
    x.append((binEdges[i] + binEdges[i+1]) / 2)

# %%
popt, pcov = curve_fit(decay, x, y) # pcov is the covariance matrix for the fit parameters

print 'Parameters of binned linear fit: tau =','%.3f'%(popt[0]),'micro sec,',' c =','%.3f'%(popt[1]),\
       ' error on tau =', '%.4f'%(np.sqrt(pcov[0][0])), 'micro sec,', \
       'error on c =', '%.4f'%(np.sqrt(pcov[1][1]))
# Out:
# Parameters of binned linear fit: tau = 2.286 micro sec,  c = 0.031  error on tau = 0.1815 micro sec, error on c = 0.0223

# %%
arange = np.arange(2, 7.05, 0.05)
plt.hist(binEdges[:-1], binEdges, weights=y, label='data')
plt.plot(arange, decay(arange, popt[0], popt[1])) #label='fit: $log_{10}(y) = -0.58 \mu s^{-1} x + 1.10$ \
         #\n cannot set intercept to 0')
plt.xlabel('Time difference between the pulses dt($\mu$s)', fontsize=12.5)
plt.xticks(fontsize=12.5)
plt.ylabel('Normalized counts', fontsize=12.5)
#plt.ylabel('$log_{10}$(counts)', fontsize=12.5)
plt.yticks(fontsize=12.5)
plt.title('Signal')
plt.legend(prop={'size': 15}, frameon=False, loc='best')

# %%
plt.hist(df['dt']*1e6, bins = 50, range=(6, 10), normed=True)
plt.xlabel('Time difference between the pulses dt ($\mu$s)', fontsize=12.5)
plt.xticks(fontsize=12.5)
plt.ylabel('counts', fontsize=12.5)
plt.yticks(fontsize=12.5)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Signal + background')
# Out:
# Text(0.5,1,'Signal + background')

# %%
y, binEdges = np.histogram(df['dt']*1e6, bins=50, range=(6, 10), density=True)
x = []
for i in range(len(y)):
    x.append((binEdges[i] + binEdges[i+1]) / 2)
x = np.asarray(x)

# %%
popt, pcov = curve_fit(decay, x, y) # pcov is the covariance matrix for the fit parameters

print 'Parameters of binned linear fit: tau =','%.3f'%(popt[0]),'micro sec,',' c =','%.3f'%(popt[1]),\
       ' error on tau =', '%.4f'%(np.sqrt(pcov[0][0])), 'micro sec,', \
       'error on c =', '%.4f'%(np.sqrt(pcov[1][1]))
# Out:
# Parameters of binned linear fit: tau = 2.672 micro sec,  c = 0.195  error on tau = 0.0717 micro sec, error on c = 0.0043

# %%
arange = np.arange(6, 10.05, 0.05)
plt.hist(binEdges[:-1], binEdges, weights=y, label='data')
plt.plot(arange, decay(arange, popt[0], popt[1]), label='fit: $y = exp(-\Delta t / 2.67) + 0.20$')
         #\n cannot set intercept to 0')
plt.xlabel('Time difference between the pulses dt($\mu$s)', fontsize=12.5)
plt.xticks(fontsize=12.5)
plt.ylabel('Normalized counts', fontsize=12.5)
#plt.ylabel('$log_{10}$(counts)', fontsize=12.5)
plt.yticks(fontsize=12.5)
plt.title('Signal + background')
plt.legend(prop={'size': 15}, frameon=True, loc='best')

# %%
getRedChi2(y, decay(x, popt[0], popt[1], popt[2]), np.sqrt(y), numPar = 3)
# Out:
# reduced chi-square = 1.26 p-value = 0.02
# 1.2603654461354326

# %%
plt.hist(df['dt']*1e6, bins = 20, range=(4.5, 5.5), normed=True)
plt.xlabel('Time difference between the pulses dt ($\mu$s)', fontsize=12.5)
plt.xticks(fontsize=12.5)
plt.ylabel('counts', fontsize=12.5)
plt.yticks(fontsize=12.5)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Signal + background')
# Out:
# Text(0.5,1,'Signal + background')

# %%
y, binEdges = np.histogram(df['dt']*1e6, bins=20, range=(4.5, 5.5), density=True)
x = []
for i in range(len(y)):
    x.append((binEdges[i] + binEdges[i+1]) / 2)
x = np.asarray(x)

# %%
popt, pcov = curve_fit(decay, x, y) # pcov is the covariance matrix for the fit parameters

print 'Parameters of binned linear fit: tau =','%.3f'%(popt[0]),'micro sec,',' c =','%.3f'%(popt[1]),\
       ' error on tau =', '%.4f'%(np.sqrt(pcov[0][0])), 'micro sec,', \
       'error on c =', '%.4f'%(np.sqrt(pcov[1][1]))
# Out:
# Parameters of binned linear fit: tau = 4.995 micro sec,  c = 0.632  error on tau = 133.2378 micro sec, error on c = 9.7968

# %%
arange = np.arange(4.5, 5.55, 0.05)
plt.hist(binEdges[:-1], binEdges, weights=y, label='data')
plt.plot(arange, decay(arange, popt[0], popt[1])) #label='fit: $log_{10}(y) = -0.58 \mu s^{-1} x + 1.10$ \
         #\n cannot set intercept to 0')
plt.xlabel('Time difference between the pulses dt($\mu$s)', fontsize=12.5)
plt.xticks(fontsize=12.5)
plt.ylabel('Normalized counts', fontsize=12.5)
#plt.ylabel('$log_{10}$(counts)', fontsize=12.5)
plt.yticks(fontsize=12.5)
plt.title('Signal + background')
plt.legend(prop={'size': 15}, frameon=False, loc='best')

# %%
f_exp = decay(x, popt[0], popt[1])
chisq, p = chisquare(y, f_exp = f_exp, ddof = 2)
print 'Chi^2/df =','%.9f'%(chisq)
# Out:
# Chi^2/df = 0.076879259

# %% [markdown]
# Fit a linear curve to the background

# %%
def linear(x, k, b):
    return k*x+b

# %%
y, binEdges = np.histogram(df['dt']*1e6, bins=20, range=(10, 20))
x = []
for i in range(len(y)):
    x.append((binEdges[i] + binEdges[i+1]) / 2)
x = np.asarray(x)

# %%
popt, pcov = curve_fit(linear, x, np.log10(y)) # pcov is the covariance matrix for the fit parameters

k_backg = popt[0]
b_backg = popt[1]

print 'Parameters of binned linear fit: slope =','%.3f'%(popt[0]),'micro sec ^ (-1),',' interceprt =','%.3f'%(popt[1]),\
       ' error on the slope =', '%.4f'%(np.sqrt(pcov[0][0])), 'micro sec ^ (-1),', \
       'error on the intercept =', '%.4f'%(np.sqrt(pcov[1][1]))
# Out:
# Parameters of binned linear fit: slope = -0.008 micro sec ^ (-1),  interceprt = 3.898  error on the slope = 0.0007 micro sec ^ (-1), error on the intercept = 0.0104

# %%
plt.hist(binEdges[:-1], binEdges, weights=np.log10(y), label='data')
plt.plot(np.arange(10, 21), linear(np.arange(10, 21), popt[0],popt[1]), label='fit: $log_{10}(y)= -0.008 \mu s^{-1} x + 3.898$')
plt.xlabel('Time between the pulses dt ($\mu$s)')
plt.ylabel('$log_{10}$(counts)')
plt.legend(prop={'size': 15}, frameon=True, loc='best')
plt.title('Background')
# Out:
# Text(0.5,1,'Background')

# %%
f_exp = linear(x, popt[0], popt[1])
chisq, p = chisquare(y, f_exp = f_exp, ddof = 2)
print 'Chi^2/df =','%.9f'%(chisq)
# Out:
# Chi^2/df = 195544077.900765151

# %% [markdown]
# Subtract the background from the data

# %%
def linear0(x, k):
    return k*x

# %%
plt.hist(df['dt']*1e6, bins = 20, range=(1.4, 3.0))
plt.xlabel('Time difference between the pulses dt ($\mu$s)', fontsize=12.5)
plt.xticks(fontsize=12.5)
plt.ylabel('counts', fontsize=12.5)
plt.yticks(fontsize=12.5)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Signal + background')
# Out:
# Text(0.5,1,'Signal + background')

# %%
y, binEdges = np.histogram(df['dt']*1e6, bins = 20, range=(2.2, 3.0))
x = []
for i in range(len(y)):
    x.append((binEdges[i] + binEdges[i+1]) / 2)
x = np.asarray(x)

# %%
y1 = np.log10(y) - (k_backg * x + b_backg)
print y1
# Out:
# [-0.24462917 -0.33945545 -0.36423099 -0.41665327 -0.4144087  -0.45577884
#  -0.47834515 -0.4942243  -0.506097   -0.51005213 -0.51953616 -0.52575295
#  -0.55545216 -0.54068589 -0.57955527 -0.60708861 -0.59252767 -0.59403559
#  -0.62018689 -0.58755885]

# %%
popt, pcov = curve_fit(linear, x, y1) # pcov is the covariance matrix for the fit parameters

print 'Parameters of binned linear fit: slope =','%.3f'%(popt[0]),'micro sec ^ (-1),',' interceprt =','%.3f'%(popt[1]),\
       ' error on the slope =', '%.4f'%(np.sqrt(pcov[0][0])), 'micro sec ^ (-1),', \
       'error on the intercept =', '%.4f'%(np.sqrt(pcov[1][1]))
# Out:
# Parameters of binned linear fit: slope = -0.396 micro sec ^ (-1),  interceprt = 0.532  error on the slope = 0.0342 micro sec ^ (-1), error on the intercept = 0.0893

# %%
arange = np.arange(1.8, 2.9, 0.05)
plt.hist(binEdges[:-1], binEdges, weights=y1, label='data')
plt.plot(arange, linear(arange, popt[0], popt[1]), label='fit: $log_{10}(y) = -0.58 \mu s^{-1} x + 1.10$ \
         \n cannot set intercept to 0')
plt.xlabel('Time difference between the pulses dt ($\mu$s)', fontsize=12.5)
plt.xticks(fontsize=12.5)
plt.ylabel('$log_{10}$(counts)', fontsize=12.5)
plt.yticks(fontsize=12.5)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Signal')
plt.legend(prop={'size': 15}, frameon=False, loc='best')

# %%
arange = np.arange(2.2, 3.0, 0.05)
plt.hist(binEdges[:-1], binEdges, weights=y1, label='data')
plt.plot(arange, linear(arange, popt[0], popt[1]), label='fit: $log_{10}(y) = -0.58 \mu s^{-1} x + 1.10$ \
         \n cannot set intercept to 0')
plt.xlabel('Time difference between the pulses dt ($\mu$s)', fontsize=12.5)
plt.xticks(fontsize=12.5)
plt.ylabel('$log_{10}$(counts)', fontsize=12.5)
plt.yticks(fontsize=12.5)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.title('Signal')
plt.legend(prop={'size': 15}, frameon=False, loc='best')

# %%
tau = -np.log10(np.e)/popt[0]
print tau
# Out:
# 1.0967668522634453

# %%
plt.hist(y1)
# Out:
# (array([6., 3., 2., 0., 2., 0., 2., 1., 2., 2.]),
#  array([-5008.74575694, -4466.02273   , -3923.29970306, -3380.57667612,
#         -2837.85364917, -2295.13062223, -1752.40759529, -1209.68456835,
#          -666.96154141,  -124.23851446,   418.48451248]),
#  <a list of 10 Patch objects>)

# %%
popt, pcov = curve_fit(decay, x, y1) # pcov is the covariance matrix for the fit parameters

print 'Parameters of binned exponential decay fit: tau =','%.3f'%(popt[0]),'micro sec,',\
    'error on tau =', '%.4f'%(np.sqrt(pcov[0][0])), 'micro sec'
# Out:
# Parameters of binned exponential decay fit: tau = 101.000 micro sec, error on tau = inf micro sec

# %%
plt.hist(binEdges[:-1], binEdges, weights=y1)
plt.plot(np.arange(10, 21), linear(np.arange(10, 21), popt[0],popt[1]), label='linear fit')
plt.xlabel('Time between the pulses dt ($\mu$s)')
plt.ylabel('Normalized number of counts')
plt.legend()

# %%
plt.hist(df['dt'], bins = 20, range=(1e-5, 2e-5))
plt.xlabel('Time difference between the pulses dt (s)', fontsize=12.5)
plt.xticks(fontsize=12.5)
plt.ylabel('Number of counts', fontsize=12.5)
plt.yticks(fontsize=12.5)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

# %%
plt.hist(df['dt']*1e6, bins=20, range=(10, 20))
plt.plot(np.arange(10, 21), linear(np.arange(10, 21), popt[0],popt[1]), label='linear fit')
plt.xlabel('Time between the pulses dt ($\mu$s)')
plt.ylabel('Normalized number of counts')
plt.legend()

# %%
log10e = 0.4342944819

# %%
# Out:
# [ 0.31147271  0.27886019  0.23515809  0.15605678  0.09166992 -0.01149019
#  -0.06926514 -0.11089162 -0.13126541 -0.15067556]

# %%
popt, pcov = curve_fit(linear, x, y1) # pcov is the covariance matrix for the fit parameters

print 'Parameters of binned exponential decay fit: slope =','%.6f'%(popt[0]),'micro sec ^ (-1),',\
    'error on the slope =', '%.4f'%(np.sqrt(pcov[0][0])), 'micro sec ^ (-1)'
# Out:
# Parameters of binned exponential decay fit: slope = -6163.348456 micro sec ^ (-1), error on the slope = 395.7342 micro sec ^ (-1)
